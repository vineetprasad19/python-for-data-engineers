# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd #pd is a module alias name

# %%
df = pd.read_csv("Data/customers-100000.csv") # df means data frames

# %%
df.head()
# Out:
#    Index      Customer Id First Name   Last Name                    Company  \
# 0      1  ffeCAb7AbcB0f07      Jared      Jarvis           Sanchez-Fletcher
# 1      2  b687FfC4F1600eC      Marie      Malone                  Mckay PLC
# 2      3  9FF9ACbc69dcF9c     Elijah     Barrera             Marks and Sons
# 3      4  b49edDB1295FF6E     Sheryl  Montgomery  Kirby, Vaughn and Sanders
# 4      5  3dcCbFEB17CCf2E     Jeremy     Houston             Lester-Manning
#
#              City                                       Country  \
# 0   Hatfieldshire                                       Eritrea
# 1  Robertsonburgh                                      Botswana
# 2         Kimbury                                      Barbados
# 3     Briannaview  Antarctica (the territory South of 60 deg S)
# 4   South Brianna                                    Micronesia
#
#                 Phone 1               Phone 2  \
# 0    274.188.8773x41185  001-215-760-4642x969
# ...

# %%
df.count()
# Out:
# Index                100000
# Customer Id          100000
# First Name           100000
# Last Name            100000
# Company              100000
# City                 100000
# Country              100000
# Phone 1              100000
# Phone 2              100000
# Email                100000
# Subscription Date    100000
# Website              100000
# Users                100000
# dtype: int64

# %%
df['Users'].max() # Returns the maximum value over the requested axis.
# Out:
# 'Vineet Prasad99999'

# %%
df['Users'].min() # Returns the minimum value over the requested axis.
# Out:
# 'Vineet Prasad1'

# %%
df[df['Users']=='Vineet Prasad1']
# Out:
#    Index      Customer Id First Name Last Name           Company  \
# 0      1  ffeCAb7AbcB0f07      Jared    Jarvis  Sanchez-Fletcher
#
#             City  Country             Phone 1               Phone 2  \
# 0  Hatfieldshire  Eritrea  274.188.8773x41185  001-215-760-4642x969
#
#                            Email Subscription Date  \
# 0  gabriellehartman@benjamin.com        11/11/2025
#
#                       Website           Users
# 0  https://www.mccarthy.info/  Vineet Prasad1

# %%
df[df['Users']=='Vineet Prasad49999']
# Out:
#        Index      Customer Id First Name  Last Name          Company  \
# 49998  49999  431eE46A0Cf1ec3   Stefanie  Castaneda  Chase-Schneider
#
#            City  Country                Phone 1            Phone 2  \
# 49998  Goodbury  Vanuatu  +1-799-345-2786x28803  852-825-1859x7379
#
#                           Email Subscription Date                 Website  \
# 49998  emma51@maxwell-bowen.com        10/15/2021  https://www.young.com/
#
#                     Users
# 49998  Vineet Prasad49999

# %%
df[df['Users']>='Vineet Prasad49999']
# Out:
#        Index      Customer Id First Name   Last Name  \
# 4          5  3dcCbFEB17CCf2E     Jeremy     Houston
# 5          6  75bEe1B33E517AF      Frank  Villarreal
# 6          7  CB8b29B8Fbbbe58     Rickey         Fox
# 7          8  56b3cEA1E6A49F1      Barry        Ware
# 8          9  f9443f5f6AF0Da0       Carl    Mcdowell
# ...      ...              ...        ...         ...
# 99994  99995  f0A7d93bCDDD215      Tyler     Collier
# 99995  99996  67F24BEBAa16d1c       Dana     Winters
# 99996  99997  17b1dbDaB2ad0fB   Gabriela     Pacheco
# 99997  99998  c586CFBA6fb9dcC    Mikayla     Hubbard
# 99998  99999  bb6cb6AC9d0CAf7     Javier        Berg
#
#                             Company                City  \
# 4                    Lester-Manning       South Brianna
# 5          Craig, Dennis and Maddox            Reidtown
# 6      Benson, Gray and Fitzpatrick        Mcintoshberg
# 7                         Glenn Ltd      Lake Pedrofort
# ...

# %%
list(df['Company'])[0].upper()
# Out:
# 'SANCHEZ-FLETCHER'

# %%
list(df['Company'])[0].lower()
# Out:
# 'sanchez-fletcher'

# %%
list(df['Company'])[51][6:15].upper().strip()
# Out:
# 'LAM AND B'

# %%
df['Company'] = df['Email'].str[6:15]

# %%
df.head()
# Out:
#    Index      Customer Id First Name   Last Name    Company            City  \
# 0      1  ffeCAb7AbcB0f07      Jared      Jarvis  llehartma   Hatfieldshire
# 1      2  b687FfC4F1600eC      Marie      Malone  ord@sexto  Robertsonburgh
# 2      3  9FF9ACbc69dcF9c     Elijah     Barrera  tecross@b         Kimbury
# 3      4  b49edDB1295FF6E     Sheryl  Montgomery  sierra@ba     Briannaview
# 4      5  3dcCbFEB17CCf2E     Jeremy     Houston  atkins@ja   South Brianna
#
#                                         Country               Phone 1  \
# 0                                       Eritrea    274.188.8773x41185
# 1                                      Botswana          283-236-9529
# 2                                      Barbados            8252703789
# 3  Antarctica (the territory South of 60 deg S)          425.475.3586
# 4                                    Micronesia  +1-223-666-5313x4530
#
#                 Phone 2                             Email Subscription Date  \
# ...

# %%
df.sort_values(by=['Subscription Date'], ascending = False)
# Out:
#        Index      Customer Id First Name  Last Name    Company  \
# 14622  14623  8Dbb8dbDe8CEbef   Gabriela      Rivas  annon@shi
# 83287  83288  F54eC5d75C07d2B    Cassidy   Mitchell  rgordon@b
# 92904  92905  1DCcE4b1Cd2468E     Joanne    Pittman  clayton@s
# 11333  11334  61D3dCde581850f      Donna      Singh  mccarthy@
# 37224  37225  bCD4Ee35Cb7B8aB     Alexis  Robertson  t@long-ba
# ...      ...              ...        ...        ...        ...
# 84352  84353  BDba3f5B1f6a4fa      Wayne      Hardy  ws@alexan
# 77347  77348  6A60acEe8fD63D4    Frances     Parker  kari@nash
# 57615  57616  f7fdb7BD0fb8BfA      Shawn     Barber  9@russo.b
# 29501  29502  3D18aaCC8ebC0c0      Jerry     Hoover  ubio@shah
# 69282  69283  DC5d742B45A2597     Krista       Tran  @mann.com
#
#                       City                           Country  \
# 14622         Lake Colleen              United Arab Emirates
# 83287            Loganberg                            Panama
# ...

# %%
df.sort_values(by=['Subscription Date'], ascending= True)
# Out:
#        Index      Customer Id First Name  Last Name    Company  \
# 3013    3014  d1038EA0cE5b930     Victor       Lowe  nrobles@r
# 4982    4983  4aA1C7545cCFF37       Fred    Blevins  @mcdonald
# 33011  33012  Dbf2827b8bc12bB     Stacey     Gamble  e86@mclea
# 89642  89643  50A714A48C98Afe     Shelia    Carroll  h@potter.
# 58801  58802  7DC3e1efC1Fd867    Carolyn    Perkins  wis@bray-
# ...      ...              ...        ...        ...        ...
# 87617  87618  84312A3bA9001Fc    Melanie  Jefferson  n33@nguye
# 70022  70023  8D8b4C32c8BeA9e    William    Sherman  ahdelacru
# 19613  19614  361Ed2d3EF0EFEE     Latoya      Wyatt  yce@webb.
# 2493    2494  3bB0cf28FC9766A     Willie   Trujillo  38@howard
# 83287  83288  F54eC5d75C07d2B    Cassidy   Mitchell  rgordon@b
#
#                   City                Country               Phone 1  \
# 3013        Trevorstad              Singapore          734.603.1366
# 4982   West Marisaview          Liechtenstein     (126)451-5145x373
# ...
