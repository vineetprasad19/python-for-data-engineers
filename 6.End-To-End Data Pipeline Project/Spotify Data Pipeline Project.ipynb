# %%
pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.25.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Collecting requests>=2.25.0 (from spotipy)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting urllib3>=1.26.0 (from spotipy)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.25.0->spotipy)
#   Downloading charset_normalizer-3.4.1-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.25.0->spotipy)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.25.0->spotipy)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Downloading spotipy-2.25.0-py3-none-any.whl (30 kB)
# Downloading redis-5.2.1-py3-none-any.whl (261 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp313-cp313-win_amd64.whl (102 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Installing collected packages: urllib3, redis, idna, charset-normalizer, certifi, requests, spotipy
# Successfully installed certifi-2025.1.31 charset-normalizer-3.4.1 idna-3.10 redis-5.2.1 requests-2.32.3 spotipy-2.25.0 urllib3-2.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="", client_secret="")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/6ZEGyHoPXcaZjO9xI7JbF5"

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2025-02-04T17:26:56Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31tetrrrrayngglzxlpmho47jx5e'},
#    'href': 'https://api.spotify.com/v1/users/31tetrrrrayngglzxlpmho47jx5e',
#    'id': '31tetrrrrayngglzxlpmho47jx5e',
#    'type': 'user',
#    'uri': 'spotify:user:31tetrrrrayngglzxlpmho47jx5e'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/2QyR1r0XwtvljXEZs9I3ge',
#     'id': '2QyR1r0XwtvljXEZs9I3ge',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e7fa423de639247fed12be4a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e7fa423de639247fed12be4a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e7fa423de639247fed12be4a',
#       'width': 64}],
#     'name': 'Main Hoon Na',
#     'release_date': '2004-02-27',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:2QyR1r0XwtvljXEZs9I3ge',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/71hjb5G92mGoKRSAW3Cj00'},
#       'href': 'https://api.spotify.com/v1/artists/71hjb5G92mGoKRSAW3Cj00',
#       'id': '71hjb5G92mGoKRSAW3Cj00',
#       'name': 'Anu Malik',
#       'type': 'artist',
#       'uri': 'spotify:artist:71hjb5G92mGoKRSAW3Cj00'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2QyR1r0XwtvljXEZs9I3ge'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dVygo6tRFXC8CSWURQJq2'},
#      'href': 'https://api.spotify.com/v1/artists/1dVygo6tRFXC8CSWURQJq2',
#      'id': '1dVygo6tRFXC8CSWURQJq2',
#      'name': 'Sonu Nigam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dVygo6tRFXC8CSWURQJq2'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0sbtGmW8r5bxfXzla8a7eI'},
#      'href': 'https://api.spotify.com/v1/artists/0sbtGmW8r5bxfXzla8a7eI',
#      'id': '0sbtGmW8r5bxfXzla8a7eI',
#      'name': 'Sabri Brothers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0sbtGmW8r5bxfXzla8a7eI'}],
#    'disc_number': 1,
#    'track_number': 8,
#    'duration_ms': 359253,
#    'external_ids': {'isrc': 'INS180461118'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1ax8ZuwRVkSdzzsIqyCNWQ'},
#    'href': 'https://api.spotify.com/v1/tracks/1ax8ZuwRVkSdzzsIqyCNWQ',
#    'id': '1ax8ZuwRVkSdzzsIqyCNWQ',
#    'name': 'Tumse Milke Dil Ka',
#    'popularity': 67,
#    'uri': 'spotify:track:1ax8ZuwRVkSdzzsIqyCNWQ',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2025-02-04T17:27:01Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31tetrrrrayngglzxlpmho47jx5e'},
#    'href': 'https://api.spotify.com/v1/users/31tetrrrrayngglzxlpmho47jx5e',
#    'id': '31tetrrrrayngglzxlpmho47jx5e',
#    'type': 'user',
#    'uri': 'spotify:user:31tetrrrrayngglzxlpmho47jx5e'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6H71erprmvRxnWs3XqC8uE',
#     'id': '6H71erprmvRxnWs3XqC8uE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a2055e0b847ff66fb5206099',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a2055e0b847ff66fb5206099',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a2055e0b847ff66fb5206099',
#       'width': 64}],
#     'name': 'Kal Ho Naa Ho (Original Motion Picture Soundtrack)',
#     'release_date': '2003-09-20',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6H71erprmvRxnWs3XqC8uE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L5GV6LN8SWWUWIdBbTLTZ'},
#       'href': 'https://api.spotify.com/v1/artists/0L5GV6LN8SWWUWIdBbTLTZ',
#       'id': '0L5GV6LN8SWWUWIdBbTLTZ',
#       'name': 'Shankar-Ehsaan-Loy',
#       'type': 'artist',
#       'uri': 'spotify:artist:0L5GV6LN8SWWUWIdBbTLTZ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6H71erprmvRxnWs3XqC8uE'},
#     'total_tracks': 7},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L5GV6LN8SWWUWIdBbTLTZ'},
#      'href': 'https://api.spotify.com/v1/artists/0L5GV6LN8SWWUWIdBbTLTZ',
#      'id': '0L5GV6LN8SWWUWIdBbTLTZ',
#      'name': 'Shankar-Ehsaan-Loy',
#      'type': 'artist',
#      'uri': 'spotify:artist:0L5GV6LN8SWWUWIdBbTLTZ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1dVygo6tRFXC8CSWURQJq2'},
#      'href': 'https://api.spotify.com/v1/artists/1dVygo6tRFXC8CSWURQJq2',
#      'id': '1dVygo6tRFXC8CSWURQJq2',
#      'name': 'Sonu Nigam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dVygo6tRFXC8CSWURQJq2'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 321240,
#    'external_ids': {'isrc': 'INS170300027'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/251PNRmJU9KcUnFQAB5t6I'},
#    'href': 'https://api.spotify.com/v1/tracks/251PNRmJU9KcUnFQAB5t6I',
#    'id': '251PNRmJU9KcUnFQAB5t6I',
#    'name': 'Kal Ho Naa Ho',
#    'popularity': 65,
#    'uri': 'spotify:track:251PNRmJU9KcUnFQAB5t6I',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2025-02-04T17:27:03Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31tetrrrrayngglzxlpmho47jx5e'},
#    'href': 'https://api.spotify.com/v1/users/31tetrrrrayngglzxlpmho47jx5e',
#    'id': '31tetrrrrayngglzxlpmho47jx5e',
#    'type': 'user',
#    'uri': 'spotify:user:31tetrrrrayngglzxlpmho47jx5e'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6iQgQoOdousn3fw6kkEhMZ',
#     'id': '6iQgQoOdousn3fw6kkEhMZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736e28d74c8eddc32542ce8924',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026e28d74c8eddc32542ce8924',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516e28d74c8eddc32542ce8924',
#       'width': 64}],
#     'name': 'Dabangg',
#     'release_date': '2010-08-04',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6iQgQoOdousn3fw6kkEhMZ',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qdu3XhzSzkRhbwdFKnSuw'},
#       'href': 'https://api.spotify.com/v1/artists/3qdu3XhzSzkRhbwdFKnSuw',
#       'id': '3qdu3XhzSzkRhbwdFKnSuw',
#       'name': 'Sajid-Wajid',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qdu3XhzSzkRhbwdFKnSuw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0El2QAwuEZvpsW2eRZiUdX'},
#       'href': 'https://api.spotify.com/v1/artists/0El2QAwuEZvpsW2eRZiUdX',
#       'id': '0El2QAwuEZvpsW2eRZiUdX',
#       'name': 'Lalit Pandit',
#       'type': 'artist',
#       'uri': 'spotify:artist:0El2QAwuEZvpsW2eRZiUdX'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6iQgQoOdousn3fw6kkEhMZ'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dVygo6tRFXC8CSWURQJq2'},
#      'href': 'https://api.spotify.com/v1/artists/1dVygo6tRFXC8CSWURQJq2',
#      'id': '1dVygo6tRFXC8CSWURQJq2',
#      'name': 'Sonu Nigam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dVygo6tRFXC8CSWURQJq2'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0oOet2f43PA68X5RxKobEy'},
#      'href': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy',
#      'id': '0oOet2f43PA68X5RxKobEy',
#      'name': 'Shreya Ghoshal',
#      'type': 'artist',
#      'uri': 'spotify:artist:0oOet2f43PA68X5RxKobEy'}],
#    'disc_number': 1,
#    'track_number': 3,
#    'duration_ms': 286720,
#    'external_ids': {'isrc': 'INS181007460'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5CteVMD0U8C9WbAWvrNgkN'},
#    'href': 'https://api.spotify.com/v1/tracks/5CteVMD0U8C9WbAWvrNgkN',
#    'id': '5CteVMD0U8C9WbAWvrNgkN',
#    'name': 'Chori Kiya Re Jiya',
#    'popularity': 63,
#    'uri': 'spotify:track:5CteVMD0U8C9WbAWvrNgkN',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2025-02-04T17:27:26Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31tetrrrrayngglzxlpmho47jx5e'},
#    'href': 'https://api.spotify.com/v1/users/31tetrrrrayngglzxlpmho47jx5e',
#    'id': '31tetrrrrayngglzxlpmho47jx5e',
#    'type': 'user',
#    'uri': 'spotify:user:31tetrrrrayngglzxlpmho47jx5e'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/5j7tLPiLgd645zG6qc5oit',
#     'id': '5j7tLPiLgd645zG6qc5oit',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6f533bfc8a8b3b9de6123cc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6f533bfc8a8b3b9de6123cc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6f533bfc8a8b3b9de6123cc',
#       'width': 64}],
#     'name': 'Hum Dono (Original Motion Picture Soundtrack)',
#     'release_date': '1961-12-30',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5j7tLPiLgd645zG6qc5oit',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CaFdVY2rhLpErUD3vQsPh'},
#       'href': 'https://api.spotify.com/v1/artists/7CaFdVY2rhLpErUD3vQsPh',
#       'id': '7CaFdVY2rhLpErUD3vQsPh',
#       'name': 'Jaidev',
#       'type': 'artist',
#       'uri': 'spotify:artist:7CaFdVY2rhLpErUD3vQsPh'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5j7tLPiLgd645zG6qc5oit'},
#     'total_tracks': 6},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5as8A4G47Ohu9NSWs3Je8U'},
#      'href': 'https://api.spotify.com/v1/artists/5as8A4G47Ohu9NSWs3Je8U',
#      'id': '5as8A4G47Ohu9NSWs3Je8U',
#      'name': 'Asha Bhosle',
#      'type': 'artist',
#      'uri': 'spotify:artist:5as8A4G47Ohu9NSWs3Je8U'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gXDpqwYNDODn7fB0RDN8J'},
#      'href': 'https://api.spotify.com/v1/artists/0gXDpqwYNDODn7fB0RDN8J',
#      'id': '0gXDpqwYNDODn7fB0RDN8J',
#      'name': 'Mohammed Rafi',
#      'type': 'artist',
#      'uri': 'spotify:artist:0gXDpqwYNDODn7fB0RDN8J'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 258386,
#    'external_ids': {'isrc': 'INH109241020'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2oaKoKA8bvgWfBi9M8wEVJ'},
#    'href': 'https://api.spotify.com/v1/tracks/2oaKoKA8bvgWfBi9M8wEVJ',
#    'id': '2oaKoKA8bvgWfBi9M8wEVJ',
#    'name': 'Abhi Na Jao Chhod Kar',
#    'popularity': 48,
#    'uri': 'spotify:track:2oaKoKA8bvgWfBi9M8wEVJ',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2025-02-04T17:28:02Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31tetrrrrayngglzxlpmho47jx5e'},
#    'href': 'https://api.spotify.com/v1/users/31tetrrrrayngglzxlpmho47jx5e',
#    'id': '31tetrrrrayngglzxlpmho47jx5e',
#    'type': 'user',
#    'uri': 'spotify:user:31tetrrrrayngglzxlpmho47jx5e'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': True,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/6Yw4204wbgmpsGTzjXBhYD',
#     'id': '6Yw4204wbgmpsGTzjXBhYD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d9afe5c70c43cb2bd34605ea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d9afe5c70c43cb2bd34605ea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d9afe5c70c43cb2bd34605ea',
#       'width': 64}],
#     'name': 'Big Dawgs',
#     'release_date': '2024-07-09',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6Yw4204wbgmpsGTzjXBhYD',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nVa6XlBFlIkF6msW57PHp'},
#       'href': 'https://api.spotify.com/v1/artists/4nVa6XlBFlIkF6msW57PHp',
#       'id': '4nVa6XlBFlIkF6msW57PHp',
#       'name': 'Hanumankind',
#       'type': 'artist',
#       'uri': 'spotify:artist:4nVa6XlBFlIkF6msW57PHp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6tYCSHLtTI54AQJFOMfU45'},
#       'href': 'https://api.spotify.com/v1/artists/6tYCSHLtTI54AQJFOMfU45',
#       'id': '6tYCSHLtTI54AQJFOMfU45',
#       'name': 'Kalmi',
#       'type': 'artist',
#       'uri': 'spotify:artist:6tYCSHLtTI54AQJFOMfU45'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6Yw4204wbgmpsGTzjXBhYD'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nVa6XlBFlIkF6msW57PHp'},
#      'href': 'https://api.spotify.com/v1/artists/4nVa6XlBFlIkF6msW57PHp',
#      'id': '4nVa6XlBFlIkF6msW57PHp',
#      'name': 'Hanumankind',
#      'type': 'artist',
#      'uri': 'spotify:artist:4nVa6XlBFlIkF6msW57PHp'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6tYCSHLtTI54AQJFOMfU45'},
#      'href': 'https://api.spotify.com/v1/artists/6tYCSHLtTI54AQJFOMfU45',
#      'id': '6tYCSHLtTI54AQJFOMfU45',
#      'name': 'Kalmi',
#      'type': 'artist',
#      'uri': 'spotify:artist:6tYCSHLtTI54AQJFOMfU45'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 190666,
#    'external_ids': {'isrc': 'INUM72400563'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0OA00aPt3BV10qeMIs3meW'},
#    'href': 'https://api.spotify.com/v1/tracks/0OA00aPt3BV10qeMIs3meW',
#    'id': '0OA00aPt3BV10qeMIs3meW',
#    'name': 'Big Dawgs',
#    'popularity': 82,
#    'uri': 'spotify:track:0OA00aPt3BV10qeMIs3meW',
#    'is_local': False},
#   'video_thumbnail': {'url': None}}]

# %%
data['items'][0]['track']['album']['id']
# Out:
# '2QyR1r0XwtvljXEZs9I3ge'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Main Hoon Na'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2004-02-27'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 10

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/2QyR1r0XwtvljXEZs9I3ge'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '2QyR1r0XwtvljXEZs9I3ge',
#   'name': 'Main Hoon Na',
#   'release_date': '2004-02-27',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/2QyR1r0XwtvljXEZs9I3ge'},
#  {'album_id': '6H71erprmvRxnWs3XqC8uE',
#   'name': 'Kal Ho Naa Ho (Original Motion Picture Soundtrack)',
#   'release_date': '2003-09-20',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/6H71erprmvRxnWs3XqC8uE'},
#  {'album_id': '6iQgQoOdousn3fw6kkEhMZ',
#   'name': 'Dabangg',
#   'release_date': '2010-08-04',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/6iQgQoOdousn3fw6kkEhMZ'},
#  {'album_id': '5j7tLPiLgd645zG6qc5oit',
#   'name': 'Hum Dono (Original Motion Picture Soundtrack)',
#   'release_date': '1961-12-30',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/5j7tLPiLgd645zG6qc5oit'},
#  {'album_id': '6Yw4204wbgmpsGTzjXBhYD',
#   'name': 'Big Dawgs',
#   'release_date': '2024-07-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6Yw4204wbgmpsGTzjXBhYD'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2025-02-04T17:26:56Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31tetrrrrayngglzxlpmho47jx5e'},
#   'href': 'https://api.spotify.com/v1/users/31tetrrrrayngglzxlpmho47jx5e',
#   'id': '31tetrrrrayngglzxlpmho47jx5e',
#   'type': 'user',
#   'uri': 'spotify:user:31tetrrrrayngglzxlpmho47jx5e'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'album',
#    'href': 'https://api.spotify.com/v1/albums/2QyR1r0XwtvljXEZs9I3ge',
#    'id': '2QyR1r0XwtvljXEZs9I3ge',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e7fa423de639247fed12be4a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e7fa423de639247fed12be4a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e7fa423de639247fed12be4a',
#      'width': 64}],
#    'name': 'Main Hoon Na',
#    'release_date': '2004-02-27',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:2QyR1r0XwtvljXEZs9I3ge',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/71hjb5G92mGoKRSAW3Cj00'},
#      'href': 'https://api.spotify.com/v1/artists/71hjb5G92mGoKRSAW3Cj00',
#      'id': '71hjb5G92mGoKRSAW3Cj00',
#      'name': 'Anu Malik',
#      'type': 'artist',
#      'uri': 'spotify:artist:71hjb5G92mGoKRSAW3Cj00'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2QyR1r0XwtvljXEZs9I3ge'},
#    'total_tracks': 10},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dVygo6tRFXC8CSWURQJq2'},
#     'href': 'https://api.spotify.com/v1/artists/1dVygo6tRFXC8CSWURQJq2',
#     'id': '1dVygo6tRFXC8CSWURQJq2',
#     'name': 'Sonu Nigam',
#     'type': 'artist',
#     'uri': 'spotify:artist:1dVygo6tRFXC8CSWURQJq2'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0sbtGmW8r5bxfXzla8a7eI'},
#     'href': 'https://api.spotify.com/v1/artists/0sbtGmW8r5bxfXzla8a7eI',
#     'id': '0sbtGmW8r5bxfXzla8a7eI',
#     'name': 'Sabri Brothers',
#     'type': 'artist',
#     'uri': 'spotify:artist:0sbtGmW8r5bxfXzla8a7eI'}],
#   'disc_number': 1,
#   'track_number': 8,
#   'duration_ms': 359253,
#   'external_ids': {'isrc': 'INS180461118'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1ax8ZuwRVkSdzzsIqyCNWQ'},
#   'href': 'https://api.spotify.com/v1/tracks/1ax8ZuwRVkSdzzsIqyCNWQ',
#   'id': '1ax8ZuwRVkSdzzsIqyCNWQ',
#   'name': 'Tumse Milke Dil Ka',
#   'popularity': 67,
#   'uri': 'spotify:track:1ax8ZuwRVkSdzzsIqyCNWQ',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1dVygo6tRFXC8CSWURQJq2',
#   'artist_name': 'Sonu Nigam',
#   'external_url': 'https://api.spotify.com/v1/artists/1dVygo6tRFXC8CSWURQJq2'},
#  {'artist_id': '0sbtGmW8r5bxfXzla8a7eI',
#   'artist_name': 'Sabri Brothers',
#   'external_url': 'https://api.spotify.com/v1/artists/0sbtGmW8r5bxfXzla8a7eI'},
#  {'artist_id': '0L5GV6LN8SWWUWIdBbTLTZ',
#   'artist_name': 'Shankar-Ehsaan-Loy',
#   'external_url': 'https://api.spotify.com/v1/artists/0L5GV6LN8SWWUWIdBbTLTZ'},
#  {'artist_id': '1dVygo6tRFXC8CSWURQJq2',
#   'artist_name': 'Sonu Nigam',
#   'external_url': 'https://api.spotify.com/v1/artists/1dVygo6tRFXC8CSWURQJq2'},
#  {'artist_id': '1dVygo6tRFXC8CSWURQJq2',
#   'artist_name': 'Sonu Nigam',
#   'external_url': 'https://api.spotify.com/v1/artists/1dVygo6tRFXC8CSWURQJq2'},
#  {'artist_id': '0oOet2f43PA68X5RxKobEy',
#   'artist_name': 'Shreya Ghoshal',
#   'external_url': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy'},
#  {'artist_id': '5as8A4G47Ohu9NSWs3Je8U',
#   'artist_name': 'Asha Bhosle',
#   'external_url': 'https://api.spotify.com/v1/artists/5as8A4G47Ohu9NSWs3Je8U'},
#  {'artist_id': '0gXDpqwYNDODn7fB0RDN8J',
#   'artist_name': 'Mohammed Rafi',
#   'external_url': 'https://api.spotify.com/v1/artists/0gXDpqwYNDODn7fB0RDN8J'},
#  {'artist_id': '4nVa6XlBFlIkF6msW57PHp',
#   'artist_name': 'Hanumankind',
#   'external_url': 'https://api.spotify.com/v1/artists/4nVa6XlBFlIkF6msW57PHp'},
#  {'artist_id': '6tYCSHLtTI54AQJFOMfU45',
#   'artist_name': 'Kalmi',
#   'external_url': 'https://api.spotify.com/v1/artists/6tYCSHLtTI54AQJFOMfU45'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  2QyR1r0XwtvljXEZs9I3ge                                       Main Hoon Na
# 1  6H71erprmvRxnWs3XqC8uE  Kal Ho Naa Ho (Original Motion Picture Soundtr...
# 2  6iQgQoOdousn3fw6kkEhMZ                                            Dabangg
# 3  5j7tLPiLgd645zG6qc5oit      Hum Dono (Original Motion Picture Soundtrack)
# 4  6Yw4204wbgmpsGTzjXBhYD                                          Big Dawgs
#
#   release_date  total_tracks  \
# 0   2004-02-27            10
# 1   2003-09-20             7
# 2   2010-08-04            10
# 3   1961-12-30             6
# 4   2024-07-09             1
#
#                                                  url
# 0  https://open.spotify.com/album/2QyR1r0XwtvljXE...
# 1  https://open.spotify.com/album/6H71erprmvRxnWs...
# 2  https://open.spotify.com/album/6iQgQoOdousn3fw...
# 3  https://open.spotify.com/album/5j7tLPiLgd645zG...
# 4  https://open.spotify.com/album/6Yw4204wbgmpsGT...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      5 non-null      object
#  1   name          5 non-null      object
#  2   release_date  5 non-null      object
#  3   total_tracks  5 non-null      int64
#  4   url           5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 332.0+ bytes

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id              song_name  duration_ms  \
# 0  1ax8ZuwRVkSdzzsIqyCNWQ     Tumse Milke Dil Ka       359253
# 1  251PNRmJU9KcUnFQAB5t6I          Kal Ho Naa Ho       321240
# 2  5CteVMD0U8C9WbAWvrNgkN     Chori Kiya Re Jiya       286720
# 3  2oaKoKA8bvgWfBi9M8wEVJ  Abhi Na Jao Chhod Kar       258386
# 4  0OA00aPt3BV10qeMIs3meW              Big Dawgs       190666
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/1ax8ZuwRVkSdzzs...          67
# 1  https://open.spotify.com/track/251PNRmJU9KcUnF...          65
# 2  https://open.spotify.com/track/5CteVMD0U8C9WbA...          63
# 3  https://open.spotify.com/track/2oaKoKA8bvgWfBi...          48
# 4  https://open.spotify.com/track/0OA00aPt3BV10qe...          82
#
#              song_added                album_id               artist_id
# 0  2025-02-04T17:26:56Z  2QyR1r0XwtvljXEZs9I3ge  71hjb5G92mGoKRSAW3Cj00
# 1  2025-02-04T17:27:01Z  6H71erprmvRxnWs3XqC8uE  0L5GV6LN8SWWUWIdBbTLTZ
# 2  2025-02-04T17:27:03Z  6iQgQoOdousn3fw6kkEhMZ  3qdu3XhzSzkRhbwdFKnSuw
# 3  2025-02-04T17:27:26Z  5j7tLPiLgd645zG6qc5oit  7CaFdVY2rhLpErUD3vQsPh
# 4  2025-02-04T17:28:02Z  6Yw4204wbgmpsGTzjXBhYD  4nVa6XlBFlIkF6msW57PHp

# %%
artist_df.head()
# Out:
#                 artist_id         artist_name  \
# 0  1dVygo6tRFXC8CSWURQJq2          Sonu Nigam
# 1  0sbtGmW8r5bxfXzla8a7eI      Sabri Brothers
# 2  0L5GV6LN8SWWUWIdBbTLTZ  Shankar-Ehsaan-Loy
# 5  0oOet2f43PA68X5RxKobEy      Shreya Ghoshal
# 6  5as8A4G47Ohu9NSWs3Je8U         Asha Bhosle
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1dVygo6tRFX...
# 1  https://api.spotify.com/v1/artists/0sbtGmW8r5b...
# 2  https://api.spotify.com/v1/artists/0L5GV6LN8SW...
# 5  https://api.spotify.com/v1/artists/0oOet2f43PA...
# 6  https://api.spotify.com/v1/artists/5as8A4G47Oh...

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  2QyR1r0XwtvljXEZs9I3ge                                       Main Hoon Na
# 1  6H71erprmvRxnWs3XqC8uE  Kal Ho Naa Ho (Original Motion Picture Soundtr...
# 2  6iQgQoOdousn3fw6kkEhMZ                                            Dabangg
# 3  5j7tLPiLgd645zG6qc5oit      Hum Dono (Original Motion Picture Soundtrack)
# 4  6Yw4204wbgmpsGTzjXBhYD                                          Big Dawgs
#
#   release_date  total_tracks  \
# 0   2004-02-27            10
# 1   2003-09-20             7
# 2   2010-08-04            10
# 3   1961-12-30             6
# 4   2024-07-09             1
#
#                                                  url
# 0  https://open.spotify.com/album/2QyR1r0XwtvljXE...
# 1  https://open.spotify.com/album/6H71erprmvRxnWs...
# 2  https://open.spotify.com/album/6iQgQoOdousn3fw...
# 3  https://open.spotify.com/album/5j7tLPiLgd645zG...
# 4  https://open.spotify.com/album/6Yw4204wbgmpsGT...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      5 non-null      object
#  1   song_name    5 non-null      object
#  2   duration_ms  5 non-null      int64
#  3   url          5 non-null      object
#  4   popularity   5 non-null      int64
#  5   song_added   5 non-null      datetime64[ns, UTC]
#  6   album_id     5 non-null      object
#  7   artist_id    5 non-null      object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 452.0+ bytes
